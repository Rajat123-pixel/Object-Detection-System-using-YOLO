# %%
# !nvidia-smi
# Out:
# Fri Aug 23 20:17:57 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.8 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
# !yolo predict model=yolov8n.pt source="https://ultralytics.com/images/bus.jpg"
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 112MB/s]
# Ultralytics YOLOv8.2.81 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 134k/134k [00:00<00:00, 6.41MB/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 80.3ms
# Speed: 10.0ms preprocess, 80.3ms inference, 910.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !pwd
# Out:
# /content

# %%
# !yolo predict model=yolov8n.pt source="images/image1.jpg"
# Out:
# Ultralytics YOLOv8.2.81 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/images/image1.jpg: 640x448 1 cat, 70.3ms
# Speed: 3.9ms preprocess, 70.3ms inference, 668.3ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # Segmentation

# %%
# !yolo task=segment mode=predict model=yolov8n-seg.pt source="images/image1.jpg"
# Out:
# ...
# 100% 6.74M/6.74M [00:00<00:00, 108MB/s]
# Ultralytics YOLOv8.2.81 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3,404,320 parameters, 0 gradients, 12.6 GFLOPs
#
# image 1/1 /content/images/image1.jpg: 640x448 1 cat, 99.6ms
# Speed: 4.2ms preprocess, 99.6ms inference, 653.2ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # Python Script

# %%
from ultralytics import YOLO

# load a segmentation model
model = YOLO('yolov8n-seg.pt')
model.predict(source="images/image1.jpg")
# Out:
# image 1/1 /content/images/image1.jpg: 640x448 1 cat, 86.9ms
# Speed: 3.9ms preprocess, 86.9ms inference, 582.8ms postprocess per image at shape (1, 3, 640, 448)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
# ...

# %% [markdown]
# # Classification

# %%
# !yolo task=classify mode=predict model=yolov8n-cls.pt source="images/image1.jpg"
# Out:
# ...
# 100% 5.31M/5.31M [00:00<00:00, 105MB/s]
# Ultralytics YOLOv8.2.81 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2,715,880 parameters, 0 gradients, 4.3 GFLOPs
#
# ...
# 100% 755k/755k [00:00<00:00, 17.3MB/s]
# image 1/1 /content/images/image1.jpg: 224x224 Egyptian_cat 0.47, tabby 0.40, tiger_cat 0.08, lynx 0.01, bow_tie 0.01, 3.0ms
# Speed: 174.5ms preprocess, 3.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.81 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.7/78.2 GB disk)

# %%
from ultralytics import yolo
from IPython.display import display, Image
# Out:
# WARNING ⚠️ Ultralytics settings reset to defaults.
# This is normal and may be due to a recent ultralytics package update, but may have overwritten previous settings.
# You may view and update settings directly in '/root/.config/Ultralytics/settings.yaml'

# %% [markdown]
# # Custom Training

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Classes
# Out:
# /content/drive/MyDrive/Classes

# %%
# !ls
# Out:
# data  YoloV8.ipynb

# %%
# %cd /content/drive/MyDrive/Classes

# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=25 imgsz=224 plots=True
# Out:
# /content/drive/MyDrive/Classes
# ...
# 100% 21.5M/21.5M [00:00<00:00, 106MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls runs/detect/train/
# Out:
# args.yaml					     R_curve.png	 train_batch122.jpg
# confusion_matrix.png				     results.csv	 train_batch1.jpg
# events.out.tfevents.1724451459.e4b6a36616bd.30905.0  results.png	 train_batch2.jpg
# F1_curve.png					     train_batch0.jpg	 val_batch0_labels.jpg
# P_curve.png					     train_batch120.jpg  val_batch0_pred.jpg
# PR_curve.png					     train_batch121.jpg  weights

# %%
Image(filename='runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/train/results.png', width=600)

# %%
Image(filename='runs/detect/train/val_batch0_pred.jpg', width=600)

# %% [markdown]
# # Validate Custom Model

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/Classes/runs/detect/train/weights/best.pt data=data.yaml
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127519 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/drive/MyDrive/Classes/data/valid/labels.cache... 4 images, 27 backgrounds, 0 corrupt: 100% 31/31 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0% 0/2 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.03s/it]
#                    all         31          8      0.703      0.286      0.241      0.155
#                Goggles         31          1          1          0          0          0
# ...

# %% [markdown]
# # Inference with custom Model

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/Classes/runs/detect/train/weights/best.pt conf=0.25 source=data/test/images
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127519 parameters, 0 gradients, 28.4 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/31 /content/drive/MyDrive/Classes/data/test/images/1.jpeg: 192x224 1 Helmet, 2 Goggless, 1 Jacket, 3 Glovess, 75.9ms
# image 2/31 /content/drive/MyDrive/Classes/data/test/images/10.jpeg: 160x224 3 Glovess, 68.4ms
# image 3/31 /content/drive/MyDrive/Classes/data/test/images/11.jpeg: 224x224 2 Glovess, 8.9ms
# image 4/31 /content/drive/MyDrive/Classes/data/test/images/12.jpeg: 192x224 3 Glovess, 11.6ms
# image 5/31 /content/drive/MyDrive/Classes/data/test/images/13.jpeg: 128x224 1 Gloves, 69.2ms
# image 6/31 /content/drive/MyDrive/Classes/data/test/images/14(1).jpeg: 224x224 9.0ms
# image 7/31 /content/drive/MyDrive/Classes/data/test/images/14.jpg: 192x224 2 Helmets, 1 Goggles, 8.4ms
# ...
